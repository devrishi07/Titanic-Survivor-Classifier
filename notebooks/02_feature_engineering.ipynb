# %%
import setup
from src.load_data import load_train
from src.transform_data import  fillna_age, add_age_group
import pandas as pd

# %%
train = load_train()

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train = fillna_age(train)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
train = add_age_group(train)
train['Age_group'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age_group
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    category
# dtypes: category(1)
# memory usage: 1.4 KB

# %%
train.groupby('Age_group')['Survived'].mean()
# Out:
# C:\Users\ruthv\AppData\Local\Temp\ipykernel_10812\38256612.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   train.groupby('Age_group')['Survived'].mean()
# Age_group
# 0-10     0.593750
# 10-20    0.382609
# 20-30    0.323607
# 30-40    0.448649
# 40-50    0.383721
# 50-60    0.404762
# 60-70    0.235294
# 70-80    0.200000
# Name: Survived, dtype: float64

# %%
from src.features import add_family_size

train = add_family_size(train)
